# %% [markdown]
# # Data Cleaning
#
# This notebook loads the raw CSV files from the raw data folder, cleans them, and writes analysis-ready CSV outputs to the data/cleaned folder.

# %%
import sys
from pathlib import Path

notebook_dir = Path.cwd().resolve()
project_root = notebook_dir.parent if notebook_dir.name == "notebook" else notebook_dir
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.data_cleaning import clean_datasets, ROOT_DIR

output_dir = ROOT_DIR / 'data' / 'cleaned'
cleaned = clean_datasets(raw_data_dir=ROOT_DIR / 'raw data', output_dir=output_dir)

print('Cleaned datasets generated:')
for name in cleaned:
    print('-', name)
# Out:
# Cleaned datasets generated:
# - customers
# - geolocation
# - order_items
# - order_payments
# - reviews
# - orders
# - products
# - sellers
# - category_translation
